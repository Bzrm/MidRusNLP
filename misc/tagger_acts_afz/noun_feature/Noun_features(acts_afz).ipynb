# %% [markdown]
# <a href="https://colab.research.google.com/github/Bzrm/MidRusNLP/blob/master/Noun_features(acts_afz).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install conllu

# %%
import conllu

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
def opener(fname):
    f = open(fname, encoding = 'utf-8')
    text = f.read()
    f.close()
    return text

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6651b2b1-e54f-4874-90bb-e139268ab574" name="files[]" multiple disabled />
#      <output id="result-6651b2b1-e54f-4874-90bb-e139268ab574">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_case.txt to true_case.txt
# Saving pred_case.txt to pred_case.txt

# %%
pred = opener('pred_case.txt').split()
true = opener('true_case.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Case')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-99bd268e-9498-4b44-a3b2-9d86acee347d" name="files[]" multiple disabled />
#      <output id="result-99bd268e-9498-4b44-a3b2-9d86acee347d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_ngender.txt to true_ngender.txt
# Saving pred_ngender.txt to pred_ngender.txt

# %%
pred = opener('pred_ngender.txt').split()
true = opener('true_ngender.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Gender')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad44a96d-f8b7-4f38-8856-f115682abe05" name="files[]" multiple disabled />
#      <output id="result-ad44a96d-f8b7-4f38-8856-f115682abe05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_nnumber.txt to true_nnumber.txt
# Saving pred_nnumber.txt to pred_nnumber.txt

# %%
pred = opener('pred_nnumber.txt').split()
true = opener('true_nnumber.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Number')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a545f52d-1334-4781-a1f8-de8e47eef28e" name="files[]" multiple disabled />
#      <output id="result-a545f52d-1334-4781-a1f8-de8e47eef28e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_animacy.txt to true_animacy.txt
# Saving pred_animacy.txt to pred_animacy.txt

# %%
pred = opener('pred_animacy.txt').split()
true = opener('true_animacy.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Animacy')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d19d8b8-7b8a-4713-aa98-2ecd05014441" name="files[]" multiple disabled />
#      <output id="result-1d19d8b8-7b8a-4713-aa98-2ecd05014441">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_Abbr.txt to true_Abbr.txt
# Saving pred_Abbr.txt to pred_Abbr.txt

# %%
pred = opener('pred_Abbr.txt').split()
true = opener('true_Abbr.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Abbr')
# Out:
# Normalized confusion matrix
