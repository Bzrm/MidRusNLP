# %% [markdown]
# <a href="https://colab.research.google.com/github/Bzrm/MidRusNLP/blob/master/Verb_features(acts_afz).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/cf/39/869a01c157b135832ce95a60a7ee75062a80e32941e00fc3d3b79331eb50/conllu-2.2-py2.py3-none-any.whl
# Installing collected packages: conllu
# Successfully installed conllu-2.2

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5cbc3a0b-bce7-484a-abaf-d8d6659d72ab" name="files[]" multiple disabled />
#      <output id="result-5cbc3a0b-bce7-484a-abaf-d8d6659d72ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_num.txt to true_num.txt
# Saving pred_num.txt to pred_num.txt

# %%
import conllu

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
def opener(fname):
    f = open(fname, encoding = 'utf-8')
    text = f.read()
    f.close()
    return text

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
pred = opener('pred_num.txt').split()
true = opener('true_num.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Number')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1beef47b-2cf9-4598-b956-1d0548bf43fd" name="files[]" multiple disabled />
#      <output id="result-1beef47b-2cf9-4598-b956-1d0548bf43fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_gend.txt to true_gend (1).txt
# Saving pred_gend.txt to pred_gend (1).txt

# %%
pred = opener('pred_gend.txt').split()
true = opener('true_gend.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Gender')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cb2617b-3b58-4425-8e73-2cb6b5270dac" name="files[]" multiple disabled />
#      <output id="result-4cb2617b-3b58-4425-8e73-2cb6b5270dac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_moo.txt to true_moo (1).txt
# Saving pred_moo.txt to pred_moo (1).txt

# %%
pred = opener('pred_moo.txt').split()
true = opener('true_moo.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Mood')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-766e73ba-d9ea-4b0c-91d3-e164d5f003b4" name="files[]" multiple disabled />
#      <output id="result-766e73ba-d9ea-4b0c-91d3-e164d5f003b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_tense.txt to true_tense.txt
# Saving pred_tense.txt to pred_tense.txt

# %%
pred = opener('pred_tense.txt').split()
true = opener('true_tense.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Tense')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4fa2d0c-4bc8-4ffe-b388-c66bbce150c1" name="files[]" multiple disabled />
#      <output id="result-a4fa2d0c-4bc8-4ffe-b388-c66bbce150c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_voice.txt to true_voice.txt
# Saving pred_voice.txt to pred_voice.txt

# %%
pred = opener('pred_voice.txt').split()
true = opener('true_voice.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Voice')
# Out:
# Normalized confusion matrix

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9db65ecd-d241-414e-a476-b174ce126de7" name="files[]" multiple disabled />
#      <output id="result-9db65ecd-d241-414e-a476-b174ce126de7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving true_person.txt to true_person.txt
# Saving pred_person.txt to pred_person.txt

# %%
pred = opener('pred_person.txt').split()
true = opener('true_person.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Person')
# Out:
# Normalized confusion matrix
