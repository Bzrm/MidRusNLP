# %%
import conllu

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
def opener(fname):
    f = open(fname, encoding = 'utf-8')
    text = f.read()
    f.close()
    return text

# %% [markdown]
# Матрица для формы глагола

# %%
pred = opener('pred_verb_form.txt').split()
true = opener('true_verb_form.txt').split()
class_names = list(set(pred))

# %%
class_names
# Out:
# ['Part', 'None', 'Fin', 'PartRes', 'Inf', 'Conv']

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Verb Form')
# Out:
# Normalized confusion matrix

# %% [markdown]
# Матрица для времени

# %%
pred = opener('pred_tense.txt').split()
true = opener('true_tense.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Tense', cmap=plt.cm.Blues)
# Out:
# Normalized confusion matrix

# %% [markdown]
# Матрица для залога

# %%
pred = opener('pred_voice.txt').split()
true = opener('true_voice.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Voice', cmap=plt.cm.Reds)
# Out:
# Normalized confusion matrix

# %% [markdown]
# Наклонение

# %%
pred = opener('pred_mood.txt').split()
true = opener('true_mood.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Mood', cmap=plt.cm.Oranges)
# Out:
# Normalized confusion matrix

# %% [markdown]
# Род

# %%
pred = opener('pred_gender.txt').split()
true = opener('true_gender.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Gender', cmap=plt.cm.Purples)
# Out:
# Normalized confusion matrix

# %% [markdown]
# Лицо

# %%
pred = opener('pred_person.txt').split()
true = opener('true_person.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Person', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix

# %% [markdown]
# Число

# %%
pred = opener('pred_number.txt').split()
true = opener('true_number.txt').split()
class_names = list(set(pred))

# %%
cnf_matrix = confusion_matrix(pred, true, labels=class_names)

# %%
np.set_printoptions(precision=2)

plt.figure(figsize = (8,8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix for Number', cmap=plt.cm.PuBu)
# Out:
# Normalized confusion matrix
